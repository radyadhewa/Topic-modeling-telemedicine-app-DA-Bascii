# %%
import pandas as pd

# %%
df = pd.read_csv("100first_halodoc_review_dataset.csv")
df
# Out:
#     annotation_id  annotator  appVersion                   created_at   id  \
# 0               6          1        23.2  2024-11-04T19:22:38.862331Z    2
# 1               7          1        23.2  2024-11-04T19:22:43.664066Z    3
# 2               8          1        23.2  2024-11-04T19:22:46.199375Z    4
# 3               9          1        23.3  2024-11-04T19:22:48.665592Z    5
# 4              10          1        23.2  2024-11-04T19:22:50.999786Z    6
# ..            ...        ...         ...                          ...  ...
# 94            100          1         NaN  2024-11-04T19:38:01.011169Z   96
# 95            101          1        23.2  2024-11-04T19:38:03.112563Z   97
# 96            102          1        23.2  2024-11-04T19:38:06.346611Z   98
# 97            103          1        23.2  2024-11-04T19:38:08.981247Z   99
# 98            104          1        23.2  2024-11-04T19:38:11.400852Z  100
#
#     lead_time                                       replyContent  \
# ...

# %%
df.to_csv("Fix_100first_halodoc_review_dataset.csv", index=True)
